# %%
import urllib
import re
import time
from threading import Thread
import MySQLdb
import mechanize
import readability
from bs4 import BeautifulSoup
from readability.readability import Document
import urlparse


class MultiScrape:
    visited = []
    urls = []
    glob_visited = []
    depth = 0
    counter = 0
    threadlist = []
    root = ""

    def __init__(self, url, depth):
       self.glob_visited.append(url)
       self.depth = depth
       self.root = url
   
    def run(self):
        while self.counter < self.depth:
            for w in self.glob_visited:
                if w not in self.visited:
                    self.visited.append(w)
                    self.urls.append(w)
            self.glob_visited = []       
            for r in self.urls:
                try: 
                    t = Thread(target=self.scrapeStep, args=(r,))
                    self.threadlist.append(t)
                    t.start()            
                except:
                    nnn = True 
            for g in self.threadlist:
                g.join() 
            self.counter+=1
        return self.visited  

    def scrapeStep(self,root):
        result_urls = []
        br = mechanize.Browser()
        br.set_handle_robots(False)
        br.addheaders = [('User-agent', 'Firefox')]
        try:
            br.open(root)
            for link in br.links():
                newurl =  urlparse.urljoin(link.base_url,link.url)
                if urlparse.urlparse(link.base_url).hostname.replace("www.","") in self.root:
                    result_urls.append(newurl)   
        except:
            err = True     
        for res in result_urls:
            self.glob_visited.append(res)
            
    






def getReadableArticle(url):
    br = mechanize.Browser()
    br.set_handle_robots(False)
    br.addheaders = [('User-agent', 'Firefox')]

    html = br.open(url).read()

    readable_article = Document(html).summary()
    readable_title = Document(html).short_title()

    soup = BeautifulSoup(readable_article)

    final_article = soup.text

    links = soup.findAll('img', src=True)

    title_article = []
    title_article.append(final_article)
    title_article.append(readable_title)
    return title_article

    



def dungalo(urls):
    article_text =getReadableArticle(urls)[0]
    d[urls] = article_text

        

def getMultiHtml(urlsList,steps):

    for urls1 in urlsList:
        try:
            t = Thread(target=scraper, args=(urls1,steps,))
            threadlist.append(t)
            t.start()            
        except:
            nnn = True

    for g in threadlist:
        g.join()

# %%
import pandas as pd
import numpy as np 
from pandas import Series
domains=pd.read_csv("all_domain.csv",header=None)
domains.head()
domains[1].values
# Out:
# array(['http://cidse.engineering.asu.edu', 'http://www.cs.bu.edu',
#        'http://azer.bestavros.net', 'http://www.bu.edu',
#        'http://orecchia.net', 'http://research.brown.edu',
#        'http://cs.brown.edu', 'http://jeffhuang.com',
#        'http://news.brown.edu', 'http://www.cs.brown.edu',
#        'http://sites.google.com', 'http://users.cms.caltech.edu',
#        'http://www.gg.caltech.edu', 'http://www.dna.caltech.edu',
#        'http://www.geometry.caltech.edu', 'http://www.cms.caltech.edu',
#        'http://people.csail.mit.edu', 'http://www.its.caltech.edu',
#        'http://www.work.caltech.edu', 'http://www.yisongyue.com',
#        'http://www.cs.cmu.edu', 'http://en.wikipedia.org',
#        'http://public.tepper.cmu.edu', 'http://alex.smola.org',
#        'http://amyogan.com', 'http://symbolaris.com',
#        'http://www-2.cs.cmu.edu', 'http://kittur.org',
#        'http://www.stat.cmu.edu', 'http://www.andrew.cmu.edu',
#        'http://mlsp.cs.cmu.edu', 'http://www.umiacs.umd.edu',
#        'http://www.chrisharrison.net', 'http://www.cmu.edu',
#        'http://users.ece.cmu.edu', 'http://www.epp.cmu.edu',
#        'http://www.ece.cmu.edu', 'http://herbsleb.org',
#        'http://www.jeffeppinger.com', 'http://dl.dropboxusercontent.com',
#        'http://goodgestreet.com', 'http://act-r.psy.cmu.edu',
#        'http://pact.cs.cmu.edu', 'http://lauradabbish.com',
#        'http://lorrie.cranor.org', 'http://spoke.compose.cs.cmu.edu',
#        'http://euro.ecom.cmu.edu', 'http://graphics.cs.cmu.edu',
#        'http://www.normsadeh.org', 'http://www.rr.cs.cmu.edu',
#        'http://www.hss.cmu.edu', 'http://murphylab.web.cmu.edu',
#        'http://kraut.hciresearch.org', 'http://www.psy.cmu.edu',
#        'http://www.midas.pitt.edu', 'http://www.hcii.cmu.edu',
#        'http://www.cnbc.cmu.edu', 'http://www.umut-acar.org',
#        'http://www.iscb.org', 'http://www.cs.columbia.edu',
#        'http://www1.cs.columbia.edu', 'http://www.columbia.edu',
#        'http://davidsjohnson.net', 'http://www.linkedin.com',
#        'http://civil.columbia.edu', 'http://engineering.columbia.edu',
#        'http://www.ee.columbia.edu', 'http://cheme.columbia.edu',
#        'http://www.clrc.rhul.ac.uk', 'http://www.cs.cornell.edu',
#        'http://tech.cornell.edu', 'http://www.graphics.cornell.edu',
#        'http://infosci.cornell.edu', 'http://www-bcf.usc.edu',
#        'http://www.cs.dartmouth.edu', 'http://web.cs.dartmouth.edu',
#        'http://bregman.dartmouth.edu', 'http://www.cs.duke.edu',
#        'http://people.ee.duke.edu', 'http://www.genome.duke.edu',
#        'http://www.duke.edu', 'http://www.ece.duke.edu',
#        'http://www.bme.duke.edu', 'http://www.ee.duke.edu',
#        'http://fds.duke.edu', 'http://stat.duke.edu',
#        'http://www.madalgo.au.dk', 'http://www.math.duke.edu',
#        'http://www.ece.illinois.edu', 'http://www.stat.duke.edu',
#        'http://www.isds.duke.edu', 'http://www.dibs.duke.edu',
#        'http://people.duke.edu', 'http://jhfc.duke.edu',
#        'http://www.cc.gatech.edu', 'http://www.cse.gatech.edu',
#        'http://www.ic.gatech.edu', 'http://home.cc.gatech.edu',
#        'http://betsydisalvo.com', 'http://www.blairmacintyre.me',
#        'http://sonify.psych.gatech.edu', 'http://www.scs.gatech.edu',
#        'http://www.provost.gatech.edu', 'http://people.math.gatech.edu',
#        'http://comp.social.gatech.edu', 'http://www.gregoryabowd.com',
#        'http://www.hichristensen.net', 'http://lance.fortnow.com',
#        'http://laurenwilcox.net',
#        'http://a4bf0b58-a-62cb3a1a-s-sites.googlegroups.com',
#        'http://www.academia.edu', 'http://mikeb.inta.gatech.edu',
#        'http://www.munmund.net', 'http://www.ti.gatech.edu',
#        'http://vuduc.org', 'http://www.iac.gatech.edu',
#        'http://taesoo.gtisc.gatech.edu', 'http://www.conte.us',
#        'http://wenke.gtisc.gatech.edu', 'http://www.seas.harvard.edu',
#        'http://coxlab.org', 'http://www.lcdf.org',
#        'http://www.eecs.harvard.edu', 'http://hips.seas.harvard.edu',
#        'http://people.seas.harvard.edu', 'http://www.cs.jhu.edu',
#        'http://www.stanford.edu', 'http://www.avirubin.com',
#        'http://spar.isi.jhu.edu', 'http://campar.in.tum.de',
#        'http://jshare.johnshopkins.edu', 'http://homepages.inf.ed.ac.uk',
#        'http://ttic.uchicago.edu', 'http://hssl.cs.jhu.edu',
#        'http://cs.jhu.edu', 'http://folio.jhu.edu',
#        'http://www.suchisaria.com', 'http://www.vuse.vanderbilt.edu',
#        'http://www.csail.mit.edu', 'http://lids.mit.edu',
#        'http://www.argentumlux.org', 'http://csg.csail.mit.edu',
#        'http://web.mit.edu', 'http://www.pmg.lcs.mit.edu',
#        'http://csbi.mit.edu', 'http://www.rle.mit.edu',
#        'http://adams.academy.ac.il', 'http://cgs.csail.mit.edu',
#        'http://www.scholars.northwestern.edu',
#        'http://groups.csail.mit.edu', 'http://nms.csail.mit.edu',
#        'http://esd.mit.edu', 'http://www.mit.edu',
#        'http://web.media.mit.edu', 'http://www.cs.ualberta.ca',
#        'http://bcs.mit.edu', 'http://pdos.csail.mit.edu',
#        'http://webcache.googleusercontent.com',
#        'http://www.scottaaronson.com', 'http://www.shiae.cuhk.edu',
#        'http://people.lids.mit.edu', 'http://cs.nyu.edu',
#        'http://cims.nyu.edu', 'http://www.cs.nyu.edu',
#        'http://mrl.nyu.edu', 'http://www.nyu.edu',
#        'http://www.news.cs.nyu.edu', 'http://vgc.poly.edu',
#        'http://as.nyu.edu', 'http://www.cs.utexas.edu',
#        'http://www.mzahran.com', 'http://www.cims.nyu.edu',
#        'http://steinhardt.nyu.edu', 'http://bonneaulab.bio.nyu.edu',
#        'http://www.shoup.net', 'http://yann.lecun.com',
#        'http://www.csc.ncsu.edu', 'http://www4.ncsu.edu',
#        'http://reeves.csc.ncsu.edu', 'http://people.engr.ncsu.edu',
#        'http://moss.csc.ncsu.edu', 'http://rouskas.csc.ncsu.edu',
#        'http://www.intellimedia.ncsu.edu',
#        'http://collaboration.csc.ncsu.edu', 'http://www.researchgate.net',
#        'http://analytics.ncsu.edu', 'http://workthatmatters.ncsu.edu',
#        'http://dbgroup.ncsu.edu', 'http://www.google.com',
#        'http://www.computer.org', 'http://dutta.csc.ncsu.edu',
#        'http://statgen.ncsu.edu', 'http://www.ece.northwestern.edu',
#        'http://ivpl.eecs.northwestern.edu',
#        'http://users.eecs.northwestern.edu',
#        'http://www.cs.northwestern.edu', 'http://archive.adl.org',
#        'http://watson.csc.ncsu.edu', 'http://segal.northwestern.edu',
#        'http://www.mech.northwestern.edu',
#        'http://www.mccormick.northwestern.edu', 'http://www.dropbox.com',
#        'http://www.eecs.northwestern.edu', 'http://spatiallearning.org',
#        'http://www.exploratorium.edu', 'http://robertdick.org',
#        'http://www.tomhinrichs.com', 'http://www.sesp.northwestern.edu',
#        'http://www.cse.ohio-state.edu', 'http://arnab.org',
#        'http://math.stanford.edu', 'http://www.abonchaudhuri.net',
#        'http://scholar.google.com', 'http://dl.acm.org',
#        'http://ece.osu.edu', 'http://discovery.osu.edu',
#        'http://medicine.osu.edu', 'http://www.colorado.edu',
#        'http://www.cse.psu.edu', 'http://www.patrickmcdaniel.org',
#        'http://www.cs.princeton.edu', 'http://randomwalker.info',
#        'http://august.princeton.edu', 'http://www.princeton.edu',
#        'http://vision.princeton.edu', 'http://reducio.princeton.edu',
#        'http://www.cs.purdue.edu', 'http://www.cs.rpi.edu',
#        'http://www.bioinfo.rpi.edu', 'http://homepages.rpi.edu',
#        'http://nlp.cs.rpi.edu', 'http://faculty.rpi.edu',
#        'http://eng.rpi.edu', 'http://www.cogsci.rpi.edu',
#        'http://webee.technion.ac.il', 'http://www.ecse.rpi.edu',
#        'http://compsci.rice.edu', 'http://www.cs.rice.edu',
#        'http://cohesion.rice.edu', 'http://blog.chron.com',
#        'http://www.cs.rutgers.edu', 'http://www.youtube.com',
#        'http://www.research.rutgers.edu', 'http://ftp',
#        'http://www.pracsyslab.org', 'http://ruccs.rutgers.edu',
#        'http://rutgers.academia.edu', 'http://www.stat.rutgers.edu',
#        'http://www.math.rutgers.edu', 'http://www.citidel.org',
#        'http://eliassi.org', 'http://seqam.rutgers.edu',
#        'http://theory.stanford.edu', 'http://anshul.kundaje.net',
#        'http://cva.stanford.edu', 'http://nlp.stanford.edu',
#        'http://cs.stanford.edu', 'http://csl.stanford.edu',
#        'http://ai.stanford.edu', 'http://verify.stanford.edu',
#        'http://www.scs.stanford.edu', 'http://vision.stanford.edu',
#        'http://bejerano.stanford.edu', 'http://infolab.stanford.edu',
#        'http://robotics.stanford.edu', 'http://arsenalfc.stanford.edu',
#        'http://geometry.stanford.edu', 'http://graphics.stanford.edu',
#        'http://vlsiweb.stanford.edu', 'http://hci.stanford.edu',
#        'http://logic.stanford.edu', 'http://suif.stanford.edu',
#        'http://yuba.stanford.edu', 'http://www-graphics.stanford.edu',
#        'http://physbam.stanford.edu', 'http://robots.stanford.edu',
#        'http://cvgl.stanford.edu', 'http://www.ibb.gatech.edu',
#        'http://www.cs.stonybrook.edu', 'http://www.cs.sunysb.edu',
#        'http://bsd7.cs.stonybrook.edu', 'http://compas.cs.stonybrook.edu',
#        'http://seclab.cs.stonybrook.edu', 'http://digitalpiglet.org',
#        'http://engineering.tamu.edu', 'http://www.cs.tamu.edu',
#        'http://faculty.cse.tamu.edu', 'http://geography.tamu.edu',
#        'http://www.cse.tamu.edu', 'http://one.arch.tamu.edu',
#        'http://www.math.tamu.edu', 'http://parasol.tamu.edu',
#        'http://cise.ufl.edu', 'http://www.cs.arizona.edu',
#        'http://arnetminer.org', 'http://cscheid.net',
#        'http://iasec.eller.arizona.edu', 'http://kobus.ca',
#        'http://dingo.sbs.arizona.edu', 'http://vishnu.eller.arizona.edu',
#        'http://www.cs.berkeley.edu', 'http://bnrg.cs.berkeley.edu',
#        'http://www.armandofox.com', 'http://www.eecs.berkeley.edu',
#        'http://math.berkeley.edu', 'http://www.stat.berkeley.edu',
#        'http://www.paulos.net', 'http://db.cs.berkeley.edu',
#        'http://goldberg.berkeley.edu', 'http://srl.cs.berkeley.edu',
#        'http://vis.berkeley.edu', 'http://people.ischool.berkeley.edu',
#        'http://niryosef.wordpress.com', 'http://www.cs.berkely.edu',
#        'http://bnrg.eecs.berkeley.edu', 'http://cocosci.berkeley.edu',
#        'http://graphics.cs.ucdavis.edu', 'http://daks.ucdavis.edu',
#        'http://www.cs.ucdavis.edu', 'http://american.cs.ucdavis.edu',
#        'http://mae.engr.ucdavis.edu', 'http://www.ics.uci.edu',
#        'http://www.cs.ucla.edu', 'http://www.stat.ucla.edu',
#        'http://research.microsoft.com', 'http://vast.cs.ucla.edu',
#        'http://biolchem.ucla.edu', 'http://bayes.cs.ucla.edu',
#        'http://oak.cs.ucla.edu', 'http://www.ee.ucla.edu',
#        'http://www.mpi-sws.org', 'http://www.math.ucla.edu',
#        'http://www.jacobsschool.ucsd.edu', 'http://db.ucsd.edu',
#        'http://cseweb.ucsd.edu', 'http://math.ucsd.edu',
#        'http://sosa.ucsd.edu', 'http://mesl.ucsd.edu',
#        'http://www.math.ucsd.edu', 'http://fleece.ucsd.edu',
#        'http://www.cs.ucsb.edu', 'http://www.engineering.ucsb.edu',
#        'http://www.cs.uchicago.edu', 'http://l3d.cs.colorado.edu',
#        'http://userpages.umbc.edu', 'http://www.cs.umd.edu',
#        'http://www.cise.ufl.edu', 'http://www.coreytoler.com',
#        'http://people.cs.clemson.edu', 'http://www.acis.ufl.edu',
#        'http://www.kevinbutler.org', 'http://www.kylamcmullen.com',
#        'http://cs.illinois.edu', 'http://akolla.cs.illinois.edu',
#        'http://wiki.engr.illinois.edu', 'http://www.cs.illinois.edu',
#        'http://cgunter.web.cs.illinois.edu', 'http://www.cs.uiuc.edu',
#        'http://sifaka.cs.uiuc.edu', 'http://l2r.cs.uiuc.edu',
#        'http://mir.cs.illinois.edu', 'http://polaris.cs.uiuc.edu',
#        'http://videolectures.net', 'http://fsl.cs.illinois.edu',
#        'http://parallel.illinois.edu', 'http://formal.cs.uiuc.edu',
#        'http://iacoma.cs.uiuc.edu', 'http://charm.cs.uiuc.edu',
#        'http://lukeo.cs.illinois.edu', 'http://lists.cs.uiuc.edu',
#        'http://pertsserver.cs.uiuc.edu', 'http://www.ranjithakumar.net',
#        'http://rutenbar.cs.illinois.edu', 'http://mobius.cs.uiuc.edu',
#        'http://sarielhp.org', 'http://rsim.cs.illinois.edu',
#        'http://www.sinhalab.net', 'http://shj.cs.illinois.edu',
#        'http://msl.cs.uiuc.edu', 'http://web.engr.illinois.edu',
#        'http://illinois.edu', 'http://www.ece.umd.edu',
#        'http://www.cfar.umd.edu', 'http://www.cbcb.umd.edu',
#        'http://www.cs.umass.edu', 'http://people.cs.umass.edu',
#        'http://web.eecs.umich.edu', 'http://ai.eecs.umich.edu',
#        'http://www.eecs.umich.edu', 'http://april.eecs.umich.edu',
#        'http://www.soe.umich.edu', 'http://sitemaker.umich.edu',
#        'http://jhalderm.com', 'http://jasonmars.org',
#        'http://www.lingjia.org', 'http://www.socialworldsresearch.org',
#        'http://www.provost.umich.edu', 'http://www.cse.unt.edu',
#        'http://www-users.cs.umn.edu', 'http://www.cs.umn.edu',
#        'http://cse.ucsd.edu', 'http://www.umsec.umn.edu',
#        'http://gandalf.psych.umn.edu', 'http://lanayarosh.com',
#        'http://www.cs.unc.edu', 'http://cs.unc.edu',
#        'http://henryfuchs.web.unc.edu', 'http://frahm.web.unc.edu',
#        'http://cci.uncc.edu', 'http://wwwx.cs.unc.edu',
#        'http://cse.nd.edu', 'http://www.cis.upenn.edu',
#        'http://www-stat.wharton.upenn.edu', 'http://www.seas.upenn.edu',
#        'http://www.crypto.com', 'http://www.cs.pitt.edu',
#        'http://people.cs.pitt.edu', 'http://www.cs.rochester.edu',
#        'http://www.pgbovine.net', 'http://cacs.usc.edu',
#        'http://sunset.usc.edu', 'http://ceng.usc.edu',
#        'http://infolab.usc.edu', 'http://sir-lab.usc.edu',
#        'http://www.ellishorowitz.com', 'http://bbdl.usc.edu',
#        'http://www-robotics.usc.edu', 'http://iris.usc.edu',
#        'http://www.hao-li.com', 'http://weblaw.usc.edu',
#        'http://www.sigmacoding.com', 'http://gridsec.usc.edu',
#        'http://www.isi.edu', 'http://ilab.usc.edu',
#        'http://bourbon.usc.edu', 'http://www.usc.edu', 'http://ee.usc.edu',
#        'http://www.cmb.usc.edu', 'http://teamcore.usc.edu',
#        'http://www-rcf.usc.edu', 'http://www.pauldebevec.com',
#        'http://pollux.usc.edu', 'http://sruti.usc.edu',
#        'http://rohslab.cmb.usc.edu', 'http://perspolis.usc.edu',
#        'http://sail.usc.edu', 'http://www-clmc.usc.edu',
#        'http://ise.usc.edu', 'http://www.idm-lab.org',
#        'http://graphics.usc.edu', 'http://halcyon.usc.edu',
#        'http://zhoulab.usc.edu', 'http://nr.com', 'http://www.cs.utah.edu',
#        'http://www.cemyuksel.com', 'http://faculty.utah.edu',
#        'http://www.pitt.edu', 'http://www.sagepub.in',
#        'http://www.ece.utah.edu', 'http://www.sci.utah.edu',
#        'http://utah.academia.edu', 'http://www.pascucci.org',
#        'http://svivek.com', 'http://cphg.virginia.edu',
#        'http://www.cs.virginia.edu', 'http://rt.cs.virginia.edu',
#        'http://www.connellybarnes.com', 'http://people.virginia.edu',
#        'http://www.cis.temple.edu', 'http://www.ece.virginia.edu',
#        'http://www.cs.washington.edu', 'http://homes.cs.washington.edu',
#        'http://djw.cs.washington.edu', 'http://www.mayacakmak.com',
#        'http://abstract.cs.washington.edu',
#        'http://suinlee.cs.washington.edu', 'http://www.cs.wisc.edu',
#        'http://pages.cs.wisc.edu', 'http://www.cs.vt.edu',
#        'http://people.cs.vt.edu', 'http://ndssl.vbi.vt.edu',
#        'http://fox.cs.vt.edu', 'http://www.cnsr.ictas.vt.edu',
#        'http://cse.wustl.edu', 'http://www.cs.yale.edu',
#        'http://www.brynosaurus.com'], dtype=object)

# %%
for dom in domains[1].values[:2]:
    MultiScrape(dom,2).run()

# %%
MultiScrape.visited
# Out:
# ['http://cidse.engineering.asu.edu',
#  'http://www.googletagmanager.com/ns.html?id=GTM-KDWN8Z',
#  'https://weblogin.asu.edu/cgi-bin/login',
#  'http://www.asu.edu/',
#  'https://my.asu.edu/',
#  'http://www.asu.edu/colleges/',
#  'http://artsandsciences.asu.edu/',
#  'http://wpcarey.asu.edu/',
#  'http://herbergerinstitute.asu.edu',
#  'http://education.asu.edu/',
#  'http://engineering.asu.edu/',
#  'http://sfis.asu.edu/',
#  'http://graduate.asu.edu',
#  'http://healthsolutions.asu.edu/',
#  'http://honors.asu.edu/',
#  'http://cronkite.asu.edu',
#  'http://www.law.asu.edu/',
#  'http://nursingandhealth.asu.edu/',
#  'http://copp.asu.edu',
#  'http://schoolofsustainability.asu.edu',
#  'http://uc.asu.edu/',
#  'http://www.thunderbird.edu/',
#  'http://www.asu.edu/map/',
#  'http://campus.asu.edu/tempe/',
#  'http://campus.asu.edu/west/',
#  'http://campus.asu.edu/polytechnic/',
#  'http://campus.asu.edu/downtown/',
#  'http://asuonline.asu.edu/',
#  'http://havasu.asu.edu/',
#  'http://skysong.asu.edu/',
#  'http://asuresearchpark.com/',
#  'http://washingtoncenter.asu.edu/',
#  'http://wpcarey.asu.edu/mba/china-program/english/',
#  'http://www.asu.edu/contactasu/',
#  'javascript:toggleASU();',
#  'http://cidse.engineering.asu.edu/',
#  'https://cidse.engineering.asu.edu',
#  'http://cidse.engineering.asu.edu/about/',
#  'http://cidse.engineering.asu.edu/about/directors-welcome/',
#  'http://cidse.engineering.asu.edu/about/our-vision/',
#  'http://cidse.engineering.asu.edu/about/annual-reports-and-newsletters/',
#  'http://engineering.asu.edu/factbook/data/',
#  'http://cidse.engineering.asu.edu/forstudent/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/preparing-for-college/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/undergraduate-admissions/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/graduate-admissions/',
#  'http://cidse.engineering.asu.edu/forstudent/undergraduate/',
#  'http://cidse.engineering.asu.edu/forstudent/undergraduate/majors/',
#  'http://cidse.engineering.asu.edu/forstudent/academic-advising/undergraduate-advising/ug-student-resource/',
#  'http://cidse.engineering.asu.edu/forstudent/undergraduate/accelerateddegreeprograms/',
#  'http://cidse.engineering.asu.edu/forstudent/undergraduate/certificates/',
#  'http://cidse.engineering.asu.edu/forstudent/undergraduate/minor/',
#  'https://cidse.engineering.asu.edu/forstudent/academic-advising/undergraduate-advising/ugforms/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/computer-engineering/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/computer-science/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/industrial-engineering/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/software-engineering/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/lean-six-sigma-black-belt/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/newly-admitted-student-information/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/handbooks/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/gradforms/',
#  'http://cidse.engineering.asu.edu/course-permission-requests/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/teachingresearch-assistantships/',
#  'http://cidse.engineering.asu.edu/forstudent/graduate/alumni/',
#  'http://cidse.engineering.asu.edu/forstudent/academic-advising/',
#  'http://cidse.engineering.asu.edu/forstudent/academic-advising/undergraduate-advising/',
#  'http://cidse.engineering.asu.edu/forstudent/academic-advising/graduate-advising/',
#  'http://cidse.engineering.asu.edu/forstudent/academic-advising/undergraduate-advising/advising-appointments/',
#  'http://cidse.engineering.asu.edu/forstudent/current-course-catalogs/',
#  'https://webapp4.asu.edu/catalog/courselist?s=CEN',
#  'https://webapp4.asu.edu/catalog/courselist?s=CPI',
#  'https://webapp4.asu.edu/catalog/courselist?s=CSE',
#  'https://webapp4.asu.edu/catalog/courselist?s=CST',
#  'https://webapp4.asu.edu/catalog/courselist?s=IEE',
#  'https://webapp4.asu.edu/catalog/courselist?s=SER',
#  'http://cidse.engineering.asu.edu/forstudent/labs/',
#  'https://cidse.engineering.asu.edu/forstudent/academic-advising/cidse-override-policy/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/faculty/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/faculty-by-research-area/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/lecturers-and-research-faculty/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/phd-students/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/emeritus/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/academic-leadership-team/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/directory/staff/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/faculty-publications/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/research-centers/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/research-advancement/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/researchbriefs/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/labs-and-research-information/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/computational-intelligence-and-algorithms/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/data-management-and-information-assurance/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/network-science-and-systems/',
#  'http://cidse.engineering.asu.edu/facultyandresearch/4-major-research-areas/software-and-systems-engineering/',
#  'http://fullcircle.asu.edu/tag/cidse/',
#  'http://innercircle.engineering.asu.edu/tag/cidse/',
#  'https://engineering.asu.edu/hiring/',
#  'https://cidse.engineering.asu.edu/outreach',
#  'http://cidse.engineering.asu.edu/outreach/intel-at-asu/',
#  'https://cidse.engineering.asu.edu/outreach/camps/',
#  'https://cidse.engineering.asu.edu/outreach/internships-jobs/cse-484-major-internship-program/',
#  'http://cidse.engineering.asu.edu/contact-us-about/',
#  'http://fullcircle.asu.edu/faculty/researcher-entrepreneur-professor-launches-virtual-lab-platform-computing-research-education/',
#  'http://fullcircle.asu.edu/research/societys-food-energy-water-challenges-require-interdisciplinary-approach/',
#  'http://fullcircle.asu.edu/research/srija-chakraborty-participates-nasa-climate-change-summer-program/',
#  'http://fullcircle.asu.edu/students/french-connection-enlightening-international-research-exchange/',
#  'http://fullcircle.asu.edu/students/asu-team-wins-first-prize-intel-cup-china/',
#  'https://cidse.engineering.asu.edu/wp-content/uploads/2016/10/cidse-rankings-2016-1024x230.jpg',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/computer-science/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/computer-systems-engineering/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/industrial-engineering/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/informatics/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/engineering-management/',
#  'http://cidse.engineering.asu.edu/forstudent/prospective-students/software-engineering/',
#  'http://fullcircle.asu.edu/tag/cidse/feed/',
#  'https://fullcircle.asu.edu/',
#  'https://fullcircle.asu.edu/students/impressive-at-igem/',
#  'https://fullcircle.asu.edu/fulton-schools/engineering-management-software-engineering-degree-programs-accredited-abet/',
#  'https://fullcircle.asu.edu/students/breaking-barriers-diversity-computer-science/',
#  'https://fullcircle.asu.edu/outreach/cubic-opens-doors-award-winning-high-school-researcher/',
#  'https://fullcircle.asu.edu/faculty/slam-dunk-machine-learning/',
#  'http://www.facebook.com/plugins/likebox.php?href=http%3A%2F%2Fwww.facebook.com%2FASU.CIDSE&width=300&height=405&colorscheme=dark&show_faces=false&border_color=%23ffffff&stream=true&header=false',
#  'http://links.asu.edu/cidseit/',
#  'https://yourfuture.asu.edu/rankings',
#  'http://www.asu.edu/copyright/',
#  'http://www.asu.edu/accessibility/',
#  'http://www.asu.edu/privacy/',
#  'http://www.asu.edu/asujobs',
#  'http://www.asu.edu/emergency/',
#  'http://www.cs.bu.edu',
#  'http://www.bu.edu/cs',
#  'http://www.bu.edu/cs/about/',
#  'http://www.bu.edu/cs/about/directions-and-contact/',
#  'http://www.bu.edu/cs/about/corporate/',
#  'http://www.bu.edu/cs/undergraduate/',
#  'http://www.bu.edu/cs/undergraduate/admissions/',
#  'http://www.bu.edu/cs/undergraduate/computer-science-major/',
#  'http://www.bu.edu/cs/undergraduate/bama-program/',
#  'http://www.bu.edu/cs/undergraduate/computer-science-minor/',
#  'http://www.bu.edu/cs/undergraduate/course-transfer/',
#  'http://www.bu.edu/cs/undergraduate/undergraduate-life/',
#  'http://www.bu.edu/cs/undergraduate/undergraduate-events/',
#  'http://www.bu.edu/cs/research/',
#  'http://www.bu.edu/cs/research/research-groups/',
#  'http://www.bu.edu/cs/research/technical-reports/',
#  'http://www.bu.edu/cs/graduate/',
#  'http://www.bu.edu/cs/graduate/admissions/',
#  'http://www.bu.edu/cs/graduate/information-for-new-graduate-students/',
#  'http://www.bu.edu/cs/graduate/masters/',
#  'http://www.bu.edu/cs/graduate/specialization-in-cyber-security/',
#  'http://www.bu.edu/cs/graduate/specialization-in-data-centric-computing/',
#  'http://www.bu.edu/cs/graduate/phd-program/',
#  'http://www.bu.edu/cs/courses/',
#  'http://www.bu.edu/cs/courses/list/',
#  'http://www.bu.edu/cs/courses/course-web-pages/',
#  'http://www.bu.edu/cs/courses/schedules/',
#  'http://www.bu.edu/cs/courses/divisional-study-courses/',
#  'http://www.bu.edu/cs/people/',
#  'http://www.bu.edu/cs/people/faculty/',
#  'http://www.bu.edu/cs/people/directory/',
#  'http://www.bu.edu/cs/people/alumni/',
#  'http://www.bu.edu/cs/people/administrative-directory/',
#  'http://www.bu.edu/cs/news/',
#  'http://www.bu.edu/cs/news/cs-connections/',
#  'http://www.bu.edu/cs/resources/',
#  'http://www.bu.edu/cs/quick-links/',
#  'http://www.bu.edu/cs/facultysearch/',
#  'http://www.bu.edu/cs/2016/09/01/bu-computer-science-welcomes-new-faculty/',
#  'http://www.bu.edu/cs/2016/10/20/terriers-at-the-annual-grace-hopper-conference/',
#  'http://www.bu.edu/cs/2016/10/17/8493/',
#  'http://www.bu.edu/cs/2016/09/16/new-cs-students-turn-out-in-force-last-night/',
#  'http://www.bu.edu/today/2016/congressional-cybersecurity-caucus-briefing/',
#  'http://www.bu.edu/cs/people/faculty/faculty-spotlight/a-vision-to-help-the-disabled/',
#  'http://www.bu.edu/cs/people/alumni/alumni-spotlight/sometimes-it-pays-to-scream-at-your-boss/',
#  'mailto:cs@bu.edu',
#  'https://trusted.bu.edu/s/1759/2-bu/giving.aspx?sid=1759&gid=2&pgid=481&cid=1146&appealcode=WEBCAS',
#  'https://www.facebook.com/BUCompSci',
#  'https://twitter.com/BUCompSci',
#  'http://www.linkedin.com/groups?about=&gid=2853567']

# %%
Series(MultiScrape.visited).to_csv("all_scraped_data.csv",index=False)

# %%
ALL_scrap=Series(MultiScrape.visited)

# %%
domains[1][:2].isin(ALL_scrap)
# Out:
# 0    True
# 1    True
# Name: 1, dtype: bool
